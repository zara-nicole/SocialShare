# %%
import functions_twitter as fs
import pandas as pd

# %%
data = fs.import_data('social_twitter.csv')

# %%
data
# Out:
#      Ticker Symbol  Entity Name  Unique ID As Of Date    Screen Name  \
# 0      nasdaq:jack     18956020   53657957 2018-07-12        JackBox
# 1      nasdaq:sonc     40349928   53658774 2018-07-12   sonicdrivein
# 2       nasdaq:wen     59553554   53659046 2018-07-12         Wendys
# 3         nyse:mcd    321430105   53660705 2018-07-12      MeEncanta
# 4         nyse:mcd   2590023517   53660706 2018-07-12       365Black
# 5         nyse:mcd     71026122   53660707 2018-07-12      McDonalds
# 6         nyse:mcd     18223550   53660708 2018-07-12           RMHC
# 7         nyse:qsr    382181996   53661189 2018-07-12   TimHortonsUS
# 8      nasdaq:jack     18956020   53648731 2018-07-11        JackBox
# 9      nasdaq:sonc     40349928   53649548 2018-07-11   sonicdrivein
# 10      nasdaq:wen     59553554   53649820 2018-07-11         Wendys
# 11        nyse:mcd    321430105   53651479 2018-07-11      MeEncanta
# 12        nyse:mcd   2590023517   53651480 2018-07-11       365Black
# ...

# %%
fs.describe_data(data)
# Out:
# ['nasdaq:jack' 'nasdaq:sonc' 'nasdaq:wen' 'nyse:mcd' 'nyse:qsr']
# ['JackBox' 'sonicdrivein' 'Wendys' 'MeEncanta' '365Black' 'McDonalds'
#  'RMHC' 'TimHortonsUS' 'McDonaldsCorp']

# %%
fs.compare_followers(data,'McDonalds','MeEncanta')
